# %%
#Here we have to predict the revenue of an ice-cream shop based on temperature for 500 days
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('https://raw.githubusercontent.com/mk-gurucharan/Regression/master/IceCreamData.csv')
dataset
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
#Independent variable = Temperature
#Dependent = Revenue

X = dataset['Temperature'].values
y = dataset['Revenue'].values

dataset.head(5)
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
#consider only 5% as test size

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05)


# Fitting Decision Tree Regression to the dataset
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
#We use reshape(-1,1) to reshape variable into single column vector
regressor.fit(X_train.reshape(-1,1), y_train.reshape(-1,1))

y_pred = regressor.predict(X_test.reshape(-1,1))
y_pred


df = pd.DataFrame({'Real Values':y_test.reshape(-1), 'Predicted Values':y_pred.reshape(-1)})
df
# Out:
#     Real Values  Predicted Values
# 0    498.757050        417.354839
# 1    798.059718        781.983795
# 2    892.947720        870.765916
# 3    437.828710        427.211360
# 4    828.296077        800.202494
# 5    827.684831        841.171427
# 6    807.541287        809.672053
# 7    406.516091        450.473207
# 8    599.364914        534.799028
# 9    427.138369        472.549343
# 10   618.172091        654.197406
# 11   467.402365        521.672804
# 12   591.173390        579.307388
# 13   698.971806        691.855484
# 14   297.499120        335.770416
# 15   532.054020        518.216105
# 16   401.924792        414.423028
# 17   566.217304        493.115468
# 18   809.463411        800.202494
# 19   505.743867        478.598509
# 20   444.826802        476.794525
# 21   425.265596        448.325981
# 22   528.380417        569.618756
# 23   607.839194        726.233771
# 24   771.789537        797.566536

# %%
#Here we can see that the predicted values are not very distant from actual values.

# %%
# Visualising the Decision Tree Regression Results 
# Red = Actual Values, Green = Predicted
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_test, y_test, color = 'red')
plt.scatter(X_test, y_pred, color = 'green')
plt.title('Decision Tree Regression')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.show()

# %%
#Plot of decision tree regression
plt.plot(X_grid, regressor.predict(X_grid), color = 'black')
plt.title('Decision Tree Regression')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.show()
